# %%
# declare a list tasks whose products you want to use as inputs
upstream = ['02-cleanup']
product = None

# %%
# Parameters
upstream = {"02-cleanup": {"nb": "/home/luiscberrocal/PycharmProjects/hacktoberfest-2023/kaggle/products/cleanup.ipynb", "clean_csv": "/home/luiscberrocal/PycharmProjects/hacktoberfest-2023/kaggle/data/house_prices_clean.csv"}}
product = {"nb": "/home/luiscberrocal/PycharmProjects/hacktoberfest-2023/kaggle/products/eda.ipynb"}

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
# log convert non gaussian columns?
# df['x'] = np.log(df['x'] +1)
# df.hist()

# %%
df = pd.read_csv(upstream['02-cleanup']['clean_csv'])

df.head()
# Out:
#    under_construction  rera  bhk_no    square_ft  ready_to_move  resale  \
# 0                   0     0       2  1300.236407              1       1
# 1                   0     0       2  1275.000000              1       1
# 2                   0     0       2   933.159722              1       1
# 3                   0     1       2   929.921143              1       1
# 4                   1     0       2   999.009247              0       1
#
#    longitude   latitude  targetprice_in_lacs  posted_by_Builder  \
# 0  12.969910  77.597960                 55.0                  0
# 1  12.274538  76.644605                 51.0                  0
# 2  12.778033  77.632191                 43.0                  0
# 3  28.642300  77.344500                 62.5                  0
# 4  22.592200  88.484911                 60.5                  0
#
#    posted_by_Dealer  posted_by_Owner  bhk_or_rk_BHK  bhk_or_rk_RK
# 0                 0                1              1             0
# ...

# %%
df.corr()
# Out:
#                      under_construction      rera    bhk_no  square_ft  \
# under_construction             1.000000  0.363826 -0.040712  -0.004204
# rera                           0.363826  1.000000  0.009547  -0.006229
# bhk_no                        -0.040712  0.009547  1.000000   0.005303
# square_ft                     -0.004204 -0.006229  0.005303   1.000000
# ready_to_move                 -1.000000 -0.363826  0.040712   0.004204
# resale                        -0.347405 -0.270351  0.014581   0.001732
# longitude                      0.006440  0.104976  0.068730  -0.012591
# latitude                      -0.000381 -0.065106  0.046930   0.000803
# targetprice_in_lacs            0.055399  0.067636  0.112283   0.402685
# posted_by_Builder              0.187078  0.112204 -0.024445  -0.001216
# posted_by_Dealer               0.168987  0.236575  0.091470  -0.005032
# posted_by_Owner               -0.227133 -0.273075 -0.085238   0.005457
# ...

# %%
plt.figure(figsize=(18, 8))
sns.heatmap(df.corr(), annot=True, cmap='YlGnBu')
plt.show()

# %%
df.hist(figsize=(12,9))
plt.tight_layout()
plt.show()
# Out:
# /tmp/ipykernel_3515658/1920561762.py:2: UserWarning: Tight layout not applied. tight_layout cannot make axes width small enough to accommodate all axes decorations
#   plt.tight_layout()

# %%
plt.figure(figsize=(10, 6))
sns.histplot(df['square_feet'], kde=False, bins=30, label='Histogram', color='skyblue', stat="count")
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~/.config/jupyterlab-desktop/jlab_server/lib/python3.8/site-packages/pandas/core/indexes/base.py:3653, in Index.get_loc(self, key)
#    3652 try:
# -> 3653     return self._engine.get_loc(casted_key)
#    3654 except KeyError as err:
#
# File ~/.config/jupyterlab-desktop/jlab_server/lib/python3.8/site-packages/pandas/_libs/index.pyx:147, in pandas._libs.index.IndexEngine.get_loc()
#
# File ~/.config/jupyterlab-desktop/jlab_server/lib/python3.8/site-packages/pandas/_libs/index.pyx:176, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:7080, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:7088, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'square_feet'
#
# ...
